# %% [markdown]
# # Classification : Food, Service, Delivery, Ambience, Price

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install iterative-stratification

# %%
from transformers import Trainer, TrainingArguments
from sklearn.preprocessing import MultiLabelBinarizer
from transformers import AutoTokenizer
from torch.utils.data import Dataset
from transformers import AutoModelForSequenceClassification
from sklearn.model_selection import train_test_split
import torch
import pandas as pd
import os
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# %%
# Load dữ liệu
df = pd.read_csv("/content/label.csv")  # hoặc dùng df trực tiếp

# Binarize nhãn
mlb = MultiLabelBinarizer()
df["labels"] = df["labels"].apply(eval)  # nếu label là dạng chuỗi list
y = mlb.fit_transform(df["labels"])

# Văn bản
texts = df["comment"].astype(str).tolist()

# %%
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base", use_fast=False)
encodings = tokenizer(texts, truncation=True, padding=True, return_tensors="pt")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
class CommentDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = torch.tensor(labels, dtype=torch.float)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item["labels"] = self.labels[idx]
        return item

dataset = CommentDataset(encodings, y)

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    "vinai/phobert-base",
    num_labels=y.shape[1],
    problem_type="multi_label_classification"
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/phobert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./results",                # nơi lưu model
    num_train_epochs=10,                    # số epoch
    per_device_train_batch_size=8,        # batch size train
    per_device_eval_batch_size=8,         # batch size eval
    logging_dir="./logs",                  # nơi lưu log
    logging_steps=100,                     # log mỗi 1000 bước
    save_total_limit=1,                    # chỉ giữ 1 checkpoint mới nhất
)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
mskf = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for train_idx, val_idx in mskf.split(texts, y):
    X_train, X_eval = [texts[i] for i in train_idx], [texts[i] for i in val_idx]
    y_train, y_eval = y[train_idx], y[val_idx]
    break  # chỉ lấy fold đầu tiên

# Tokenize
train_encodings = tokenizer(X_train, padding=True, truncation=True, return_tensors="pt")
eval_encodings = tokenizer(X_eval, padding=True, truncation=True, return_tensors="pt")

# Dataset
train_dataset = CommentDataset(train_encodings, y_train)
eval_dataset = CommentDataset(eval_encodings, y_eval)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset  # <-- bắt buộc nếu eval_strategy != "no"
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='510' max='510' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [510/510 54:52, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.473100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.281900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.166000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.109900</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.079900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=510, training_loss=0.21914206965296876, metrics={'train_runtime': 3299.1153, 'train_samples_per_second': 1.231, 'train_steps_per_second': 0.155, 'total_flos': 106408676911320.0, 'train_loss': 0.21914206965296876, 'epoch': 10.0})

# %%
def predict_labels(texts):
    inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    inputs = {k: v.to(device) for k, v in inputs.items()}

    model.eval()
    with torch.no_grad():
        outputs = model(**inputs)
        probs = torch.sigmoid(outputs.logits)  # multi-label
        preds = (probs > 0.5).int()  # ngưỡng phân loại
    return preds.cpu().numpy()

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    "/content/drive/MyDrive/GRAB/results/checkpoint-9201",
    # num_labels=5,
    # problem_type="multi_label_classification"
)

# %%
reviews = pd.read_csv("/content/reviews.csv")
# Out:
# <ipython-input-16-4cc69914cc96>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews = pd.read_csv("/content/reviews.csv")

# %%
import re

# Danh sách các từ nối muốn split
conjs = ["nhưng", "mà", "bởi vì", "tuy nhiên", "và", "hay", "hoặc", "hoặc là", "cũng như", "vì vậy", "do đó", "thế nhưng", "thế mà", "dù sao đi nữa", "cũng như là", "lẫn", "cùng", "ngoài ra", "vì", "bởi vì", "nên", "vậy", "do đó", "nếu", "trừ phi", "trừ khi", "hễ", "hơn", "bằng", "như", "mặc dù", "dù chơ", "tuy nhiên", "sau khi", "khi", "để nhằm", "mục đích", "ngược lại"]
# Xây pattern: non-capturing group của (dấu câu hoặc từ nối), rồi có thể kèm space
pattern = r"(?:[\.!\?;,]+|\b(?:" + "|".join(map(re.escape, conjs)) + r")\b)\s*"

def segment_sentences(text):
    # re.split với pattern này sẽ loại bỏ luôn phần separator
    parts = re.split(pattern, str(text))
    # strip và loại bỏ empty
    return [p.strip() for p in parts if p.strip()]

# Ví dụ apply lên DataFrame
test = reviews["review_text"][:10].apply(segment_sentences)

# %%
texts = []
for components in test:
  for component in components:
    texts.append(component)

# %%
# test_comments = [
#     "Món ăn dở, giao hàng rất chậm",
#     "Giá cao mà phục vụ thì tệ",
#     "Đóng gói đẹp, nhân viên thân thiện"
# ]
label_names = ["ambience", "delivery", "food", "price", "service"]

predictions = predict_labels(texts)

for text, pred in zip(texts, predictions):
    labels = tuple(label_names[i] for i, val in enumerate(pred) if val == 1)
    print(f"\n📝 {text}\nLabels: {labels}")
# Out:
# 📝 nói chung là quá dỡ quá dơ
# Labels: ('ambience',)
#
# 📝 đặt gà bơ tỏi nhưng lại giao gà thường
# Labels: ('delivery', 'service')
#
# 📝 Đóng gói chưa tốt
# Labels: ('service',)
#
# 📝 Sai/Thiếu món
# Labels: ('food', 'service')
#
# 📝 nước đâu
# Labels: ('food',)
#
# 📝 lúc nhìn đơn nên để ý chút nha :)
# Labels: ('service',)
#
# 📝 gà ngon
# Labels: ('food',)
#
# 📝 đến nơi vẫn còn nóng
# Labels: ('ambience',)
#
# 📝 không có dưa chua
# Labels: ('service',)
#
# 📝 chỉ có mỗi túi tương cà
# Labels: ('service',)
#
# 📝 có đặt thêm phần cải thìa nhưng ko thấy đâu
# Labels: ('service',)
#
# 📝 nhà hàng làm món quá lau mình đợi hơn 1 tieng đong hồ mới có món an
# Labels: ('food',)
#
# 📝 đói mà cào ruot lun
# Labels: ('delivery',)
#
# 📝 com thì khẩu phan ít cục bò nhỏ xíu như cho e bé an
# Labels: ('food', 'price')
#
# 📝 Không hợp khẩu vị
# Labels: ('food',)
#
# 📝 thức ăn nhạt
# Labels: ('food',)
#
# 📝 hình như không có mắm tỏi ăn nhạt toẹt
# Labels: ('delivery', 'food', 'service')
#
# 📝 quá nhiều dầu
# Labels: ('food',)
#
# 📝 đồ chua chưa đủ chua
# Labels: ('delivery', 'food')
#
# 📝 23k đc 5 miếng
# Labels: ('price',)
#
# 📝 xôi ngon mà nguội tanh
# Labels: ('food',)
#
# 📝 đặt size L thêm nha đam thì giao cho mình size M ko có nha đam :))
# Labels: ('delivery', 'food', 'service')
#
# 📝 giá tiền 70k xuất mag làm bôi bác
# Labels: ('price',)
#
# 📝 thiếu 1 chai coca
# Labels: ('service',)
#
# 📝 thiếu trân châu
# Labels: ('service',)
#
# 📝 Đóng gói chưa tốt
# Labels: ('service',)
#
# 📝 quán cho thiếu canh
# Labels: ('service',)
#
# 📝 làm rất lâu
# Labels: ('delivery',)
#
# 📝 ăn tô 45k mà lạ lắm
# Labels: ('food', 'price')
#
# 📝 cơm với dưa chua ăn sộc mùi thiu
# Labels: ('food', 'service')
#
# 📝 thịt cũng bị chua
# Labels: ('food',)
#
# 📝 Mua hộp cơm 45k ko ăn được luôn á 🥲
# Labels: ('food', 'price', 'service')
#
# 📝 quá dở
# Labels: ('food',)
#
# 📝 ăn vô rất nhạt
# Labels: ('food',)
#
# 📝 ít mì nữa chứ không đáng tiền chút nào
# Labels: ('price',)
#
# 📝 Không giao
# Labels: ('delivery', 'service')
#
# 📝 đặt bánh ca cao mà giao bánh chanh leo là sao
# Labels: ('delivery', 'food')
#
# 📝 mì xào quá tệ nhìn hk muốn ăn
# Labels: ('food',)
#
# 📝 Đã ghi chú:
# Labels: ('service',)
#
# 📝 Không lấy mắm cay mà cho một đống ớt
# Labels: ('food', 'service')
#
# 📝 dính vào bánh ướt
# Labels: ('food',)
#
# 📝 phải rữa bánh ướt bằng nước lạnh cho trôi hết ớt cay mới ăn được
# Labels: ('food',)
#
# 📝 món ăn ngon
# Labels: ('food',)
#
# 📝 hợp khẩu vị của cả nhà
# Labels: ('food',)
#
# 📝 cám ơn nhà hàng nhiều
# Labels: ('food',)
#
# 📝 ăn chán hơn cả pizza hut
# Labels: ('food',)
#
# 📝 thịt gỏi cuốn bị ôi thiêu
# Labels: ('food',)
#
# 📝 cả nhà ăn bị đau bụng
# Labels: ('food',)
#
# 📝 đặt hai xuất cơm giao 1 cơm một trứng ốp
# Labels: ('delivery', 'food')
#
# 📝 total 51k
# Labels: ('price',)
#
# 📝 1 cơm 1 canh
# Labels: ('food',)
#
# 📝 Không đảm bảo vệ sinh
# Labels: ('ambience',)
#
# 📝 cơm thì a shiper báo giá tai quán mắc hơn giá trên app 5k
# Labels: ('food', 'price')
#
# 📝 Thanh toán thẻ visa vẫn bị trừ đủ 51k
# Labels: ('price',)
#
# 📝 Trải nghiệm lần đầu vs Be rất tệ
# Labels: ('service',)
#
# 📝 Bánh mì lần nào đặt cũng không nóng
# Labels: ('food', 'service')
#
# 📝 đồ ăn thì nguội
# Labels: ('food',)
#
# 📝 Not delicious
# Labels: ('food',)
#
# 📝 uống đến cuối cốc mới phát hiện một cục giấy ăn rất to đã nhuộm màu trà nhài :)
# Labels: ('food',)
#
# 📝 order có trân châu nhưng quán cho 2 cái ống nhỏ
# Labels: ('delivery', 'food')
#
# 📝 Mì nhạt nhẽo hôi mùi măng
# Labels: ('food',)
#
# 📝 ko có vị giống mì cay mà như mì gói nước xôi để topping
# Labels: ('food', 'service')
#
# 📝 ko giống mì cay mình từng ăn
# Labels: ('food', 'service')
#
# 📝 xúch xích rẻ tiền quá bở
# Labels: ('food',)
#
# 📝 đồ ăn và uống giống như đồ cũ đã lên men
# Labels: ('food',)
#
# 📝 Siêu ít đồ ăn
# Labels: ('food', 'price')
#
# 📝 không đáng giá 45k
# Labels: ('price',)
#
# 📝 Đóng gói chưa tốt
# Labels: ('service',)
#
# 📝 Không hợp khẩu vị
# Labels: ('food',)
#
# 📝 nó còn bị đông khúc giữa
# Labels: ('food',)
#
# 📝 đã v nước tương với bù tạt bị đắng còn gừng thì rã đông thấy gớm luônnnn mắc ói vô cùng không nên mua nha mn
# Labels: ('food', 'service')
#
# 📝 nãy mà mua thêm gà chắc tức chết
# Labels: ('food',)
#
# 📝 đã note không mỡ hành
# Labels: ('food', 'service')
#
# 📝 không đồ chua nhưng ngập luôn
# Labels: ('service',)
#
# 📝 Mua thêm dưa mắm vẫn tính tiền mà quán k đưa thêm làm mất 15k tiền thêm dưa mà k giao
# Labels: ('delivery', 'food', 'price')
#
# 📝 quá ít
# Labels: ('price',)
#
# 📝 bỏ thiếu topping
# Labels: ('service',)
#
# 📝 Chưa giao hàng nhưng báo là đã giao hàng thành công
# Labels: ('delivery',)
#
# 📝 trong bánh tráng trộn có tóc
# Labels: ('food',)
#
# 📝 không dùng liền mới note là đá riêng
# Labels: ('service',)
#
# 📝 đã mua nhiều lần đá riêng mà nói với shipper là ko làm được mặc dù shipper đã nhắc
# Labels: ('service',)
#
# 📝 cũng ko hề gọi lại cho khách để xác nhận được hay ko việc để đá chung
# Labels: ('service',)
#
# 📝 đặt đơn 15p mới có tài xế nhận đơn
# Labels: ('delivery',)
#
# 📝 mình kêu huỷ rồi mà vẫn giao
# Labels: ('delivery',)
#
# 📝 Đặt 4 cặp giao 4 cái chân gà
# Labels: ('delivery', 'service')
#
# 📝 nhờ để bún riêng dùm mà vẫn để chung luôn
# Labels: ('service',)
#
# 📝 giao mỳ Sào ốc móng tay
# Labels: ('food',)
#
# 📝 Không làm đúng ghi chú
# Labels: ('service',)
#
# 📝 thiếu nem rán nhé
# Labels: ('service',)
#
# 📝 vịt đỏ lòm
# Labels: ('food',)
#
# 📝 mỡ kinh khủng
# Labels: ('food',)
#
# 📝 ăn k nuốt được
# Labels: ('food',)
#
# 📝 cơm cần nhiều sốt hơn
# Labels: ('food',)
#
# 📝 thiếu món
# Labels: ('service',)
#
# 📝 quán làm ăn như cức
# Labels: ('food', 'service')
#
# 📝 bún bị chua cảm giác như sắp hỏng đến nơi rồi
# Labels: ('food',)
#
# 📝 Trà sữa khá ngon nên cty mình thường đặt chung
# Labels: ('food',)
#
# 📝 nhưng quán mắc hết lỗi này đến lỗi khác liên tục
# Labels: ('service',)
#
# 📝 Và pudding mình đã dặn trước rồi vẫn mắc lỗi lần 2
# Labels: ('service',)
#
# 📝 Hời hợt thế nào ý ạ
# Labels: ('service',)
#
# 📝 thiếu trân châu
# Labels: ('service',)
#
# 📝 làm mặn như gì zay
# Labels: ('food',)
#
# 📝 tụi bây ăn được ko mà bán cho người khác
# Labels: ('food', 'price', 'service')
#
# 📝 tại sao đặt nước lẫu sin cay mà giao nước lẫu kim chi hả
# Labels: ('delivery', 'service')
#
# 📝 thiếu nhiều thứ
# Labels: ('service',)
#
# 📝 cả phòng bọn mình ăn bị đau bụng ỉa chảy thật sự rât kinh khủng
# Labels: ('food',)
#
# 📝 mình gọi thêm thạch dừa nhưng k cho thạch dừa vậy là mình mất oan tiền toping à
# Labels: ('food', 'price', 'service')
#
# 📝 để menu trên app nhưng khi tài xế đến thì báo ko có
# Labels: ('service',)
#
# 📝 cũng ko gọi hỏi khách thay thế order món gì luôn
# Labels: ('delivery', 'service')
#
# 📝 ly trà lựu đỏ đặt là có thêm phô mai tươi mà k có 1 miếng nào
# Labels: ('food',)
#
# 📝 gọi xuất đặc biệt có sườn mà ko có
# Labels: ('delivery', 'service')
#
# 📝 ngọt ko uống được
# Labels: ('food',)
#
# 📝 rau má mà còn bị chua là thấy quán làm vệ sinh tệ cỡ nào r á
# Labels: ('food', 'service')
#
# 📝 bánh phồng tôm thì bị hôi dầu
# Labels: ('food',)
#
# 📝 50k ăn đc 1 ly xoài ( cũng ko ngon lắm) mn nghĩ kỹ trc khi đặt món
# Labels: ('food', 'price', 'service')
#
# 📝 giao đồ uống mà ko có ống hút sao uống
# Labels: ('delivery', 'service')
#
# 📝 Đóng gói chưa tốt
# Labels: ('service',)
#
# 📝 thịt sống
# Labels: ('food',)
#
# 📝 đồ ăn thui ko đảm bảo chất lượng quá thất vọng
# Labels: ('food', 'service')
#
# 📝 phần da không giòn
# Labels: ('food',)
#
# 📝 ướp nhạt vị
# Labels: ('food',)
#
# 📝 rau già
# Labels: ('food',)
#
# 📝 cứng
# Labels: ('food',)
#
# 📝 thiếu 1 phần bò lúc lắc
# Labels: ('service',)
#
# 📝 nhìn k liên quan đến ảnh :)
# Labels: ('food',)
#
# 📝 xin thêm 1 ly đá không có
# Labels: ('service',)
#
# 📝 không có nước chấm
# Labels: ('service',)
#
# 📝 rau sống mà làm rau chín
# Labels: ('service',)
#
# 📝 ăn xong đau bụng bị ẻ chảy
# Labels: ('food',)
#
# 📝 thức ăn chất lượng quá tệ
# Labels: ('food',)
#
# 📝 note rõ ràng ly trà đào nhân viên ko nỡ gọi xác nhận lấy 1 lần tự ý làm theo ý mình
# Labels: ('delivery', 'service')
#
# 📝 cách phục vụ tệ v chúc shop mau sớm vắng khách
# Labels: ('service',)
#
# 📝 nước chấm dở quá
# Labels: ('food',)
#
# 📝 giao thiêud phần mì ý mà điện thoại bao ko đc
# Labels: ('delivery', 'service')
#
# 📝 mắm tôm không khác gì nước
# Labels: ('food',)
#
# 📝 bún đậu 45k là đắt so với chả và bún đậu có trong thực đơn
# Labels: ('price',)
#
# 📝 vị mắm tôm rất tệ
# Labels: ('food',)
#
# 📝 ĐÂY LÀ GÀ TẮM NƯỚC MẮM À
# Labels: ('food',)
#
# 📝 NẾU KHÔNG CÒN THÌ BÁO KHÁCH HUỶ ĐƠN CHỨ KHÔNG PHẢI ĐẶT GÀ TẮM NƯỚC MẮM MÀ SHIP CHO KHÁCH CÁI KIỂU NÀY
# Labels: ('delivery', 'service')
#
# 📝 không có thạch băng tuyết
# Labels: ('service',)
#
# 📝 nước rất tệ
# Labels: ('food',)
#
# 📝 toàn hành tây
# Labels: ('food',)
#
# 📝 trong phần mô tả có xúc xích
# Labels: ('food',)
#
# 📝 sinh tố mà tách nước luôn
# Labels: ('food',)
#
# 📝 sinh tố bơ uống cứ bị ngứa ngứa trong miệng
# Labels: ('food',)
#
# 📝 thấy 1 cọng định rọi đèn để chụp lại mà rọi lên thành thấy 3 cọng luôn :)))
# Labels: ('food',)
#
# 📝 Nước sấu bị lên men quá mức
# Labels: ('food',)
#
# 📝 Mắm thì lạnh ngắt
# Labels: ('food',)
#
# 📝 trân châu đen sượng
# Labels: ('food',)
#
# 📝 trên hình đùi nhận lại là 2 miếng gần phao câu
# Labels: ('food',)
#
# 📝 trong hình thì ly bự
# Labels: ('food',)
#
# 📝 PhinDi thì ngọt gắt luôn
# Labels: ('food',)
#
# 📝 Not hygienic
# Labels: ('food', 'service')
#
# 📝 nước mà có miếng gì màu xanh vậy quán
# Labels: ('food',)
#
# 📝 chỉ toàn đầu mỡ
# Labels: ('food',)
#
# 📝 kim bắp chỉ chiên 1 lần
# Labels: ('food',)
#
# 📝 canh rong biển thì chỉ toàn nước
# Labels: ('food',)
#
# 📝 sữa đậu hỏng
# Labels: ('food',)
#
# 📝 nước me của quán dùng cốc đac sử dụng
# Labels: ('food', 'service')
#
# 📝 đặt 2 đậu xanh sữa dừa mà làm có 1 phần đậu xanh sữa dừa
# Labels: ('service',)
#
# 📝 k thèm cho tương cà luôn
# Labels: ('service',)
#
# 📝 bảo nước mắm cho mắm tôm
# Labels: ('service',)
#
# 📝 đặt ốc mỡ mà làm ốc bông
# Labels: ('service',)
#
# 📝 đặt tương cà thit cho tương ớt
# Labels: ('service',)
#
# 📝 2 coca lon thì được mỗi 1 chai coca
# Labels: ('service',)
#
# 📝 đặt 2 ly nước mà cho đúng nửa bịch đá
# Labels: ('service',)
#
# 📝 k cho đũa thìa
# Labels: ('service',)
#
# 📝 sốt mè mà đưa mazone
# Labels: ('service',)
#
# 📝 ô long sữa ngũ cốc size M mà lại làm ngược
# Labels: ('service',)
#
# 📝 dặn cả tài xế nhắc quán r mà vẫn cho
# Labels: ('service',)
#
# 📝 nma cho đc 1 đôi đũa
# Labels: ('service',)
#
# 📝 tính tiền ly lớn làm ly nhỏ là sao
# Labels: ('service',)
#
# 📝 lần đầu uóng ở đây trải nghiẹm quá tệ
# Labels: ('service',)
#
# 📝 bán hàng có tâm dùm
# Labels: ('service',)
#
# 📝 tại sao gọi đen đá lại cho đường ạ
# Labels: ('service',)
#
# 📝 tiger sugar mà lại là cốc royaltea
# Labels: ('service',)
#
# 📝 ống hút dính nước
# Labels: ('food',)
#
# 📝 dặn đá riêng mà vẫn để chung
# Labels: ('service',)
#
# 📝 k đúng đơn đặc hàng
# Labels: ('service',)
#
# 📝 kêu để đá riêng vẫn để dá chung chán thiệt sự
# Labels: ('service',)
#
# 📝 bỏ thêm tiền mua nước sâm mà nhận lại là coca
# Labels: ('service',)
#
# 📝 Đặt Trân châu đường đen mà lấy trân châu trắng
# Labels: ('service',)
#
# 📝 Hết sản phẩm mà vẫn để bán
# Labels: ('service',)
#
# 📝 kh có trân châu phô mai dẻo
# Labels: ('service',)
#
# 📝 đặt 3 suất mà cho chung hết vào với nhau
# Labels: ('service',)
#
# 📝 dứa còn để nguyên mắt
# Labels: ('service',)
#
# 📝 cà rốt còn nguyên vỏ
# Labels: ('service',)
#
# 📝 chọn đá chung mà cứ để đá riêng
# Labels: ('service',)
#
# 📝 trong khi mình gọi món trà tắc thạch băng tuyết là chính
# Labels: ('food',)
#
# 📝 đặt canh rong biển tự đổi canh kim chi mà ko báo khach
# Labels: ('delivery', 'food', 'service')
#
# 📝 ko cho tô xốp
# Labels: ('service',)
#
# 📝 Đặt 2 suất nhưng giao 1 suất
# Labels: ('delivery', 'service')
#
# 📝 Đóng gói chưa tốt
# Labels: ('service',)
#
# 📝 thiéuu đũa và thìa thì khách ăn làm sao
# Labels: ('service',)
#
# 📝 mì sượng
# Labels: ('food',)
#
# 📝 chưa chín
# Labels: ('food',)
#
# 📝 tok mùi hăng k thấm vị
# Labels: ('food',)
#
# 📝 gimbap tạm ổn
# Labels: ('food',)
#
# 📝 gà ngon
# Labels: ('food',)
#
# 📝 gần hết món thì tắt trên app đi chứ
# Labels: ('service',)
#
# 📝 tới khi khách đặt lại báo hết món
# Labels: ('service',)
#
# 📝 còn ko cho huỷ món như shoppee food
# Labels: ('service',)
#
# 📝 bắt khách đổi
# Labels: ('delivery', 'service')
#
# 📝 ng ta ko thik món đó thì sao
# Labels: ('service',)
#
# 📝 cá lm k sạch tanh k chịu nổi
# Labels: ('ambience', 'food')
#
# 📝 thiếu 2 cây nem mình luôn nha
# Labels: ('service',)
#
# 📝 Giao thiếu món
# Labels: ('delivery', 'service')
#
# 📝 Dụng cụ ko vệ sinh
# Labels: ('ambience', 'service')
#
# 📝 vầy thì ai dám đảm bảo nước có vệ sinh ko
# Labels: ('ambience', 'service')
#
# 📝 gọi ly Chesse Ball size L mà ko có 1 miếng topping nào
# Labels: ('food', 'price', 'service')
#
# 📝 Chỉ có ly topping mà mình gọi thêm để riêng ở ngoài
# Labels: ('food', 'service')
#
# 📝 Ủa vậy trong ly mình gọi là ko có topping luôn nếu mình ko add thêm à
# Labels: ('food', 'price', 'service')
#
# 📝 thiếu nước :)
# Labels: ('delivery', 'food', 'service')
#
# 📝 sai thiếu móm
# Labels: ('delivery', 'service')
#
# 📝 đơn chuẩn bị thiếu cả 5 câi nem chua
# Labels: ('service',)
#
# 📝 làm ăn ko cẩn thậm gì cả
# Labels: ('service',)
#
# 📝 mặn thế
# Labels: ('food',)
#
# 📝 thái độ nhân viên cọc và tác phong không đúng  và khi feedback thì nói huỷ order
# Labels: ('service',)
#
# 📝 mua 5 ly nước dừa thơm mà lạt
# Labels: ('food',)
#
# 📝 có mùi như bị hư
# Labels: ('food',)
#
# 📝 như là mùi uốn tóc
# Labels: ('food',)
#
# 📝 hôm trước đặt lần đầu (mì cay bò) ăn thấy rất ngon
# Labels: ('food',)
#
# 📝 topping nhiều đầy đủ như mô tả
# Labels: ('food',)
#
# 📝 nước dùng ok mà nay đặt lại thất vọng thật sự
# Labels: ('food',)
#
# 📝 mì cay bò chỉ có bò k có xúc xích hay cá viên gì cả
# Labels: ('food', 'service')
#
# 📝 nước thì dùng thì lạt nhách
# Labels: ('food',)
#
# 📝 còn gà viên lắc ăn ok
# Labels: ('food',)
#
# 📝 nhạt toẹt chả có vị ngọt gì
# Labels: ('food',)
#
# 📝 quán bán lừa bịp
# Labels: ('food',)
#
# 📝 1 phần như này ăn tại chỗ ko tới 50k
# Labels: ('price', 'service')
#
# 📝 quán đưa cái mác khuyến mãi vào nâng lên 75k
# Labels: ('food', 'price')
#
# 📝 giao thiếu 1 phần bì
# Labels: ('delivery', 'service')
#
# 📝 thế tôi ăn cơm không à
# Labels: ('food', 'service')
#
# 📝 giao có 2 món thiếu 3 món 2 cơm và rau
# Labels: ('delivery', 'service')
#
# 📝 không có mì
# Labels: ('food', 'service')
#
# 📝 59k mà cho cái đùi gà ăn buồn nôn
# Labels: ('food', 'price')
#
# 📝 ăn xong tầm 15' đau bụng kinh khủng
# Labels: ('food',)
#
# 📝 ra vào nvs liên tục trong khi cả tối ăn mỗi đồ của cửa hàng
# Labels: ('ambience', 'food', 'service')
#
# 📝 k biết có đảm bảo vệ sinh an toàn tp hay k nữa
# Labels: ('service',)
#
# 📝 nhưng ship 4 cốc M
# Labels: ('delivery', 'service')
#
# 📝 kimbapchiên bị cháy
# Labels: ('food',)
#
# 📝 cứng
# Labels: ('food',)
#
# 📝 cơm chỗ sống
# Labels: ('food',)
#
# 📝 sốt k đc ngon
# Labels: ('food',)
#
# 📝 ko có đào ngâm
# Labels: ('delivery', 'food', 'service')
#
# 📝 k như trên hình quá dở
# Labels: ('food',)
#
# 📝 heo quay mỡ không
# Labels: ('food',)
#
# 📝 Đặt 2 cơm gà sốt me giao thành 1 suất cơm gà với 1 cơm thịt chiên
# Labels: ('delivery', 'food', 'service')
#
# 📝 Gửi yêu cầu hỗ trợ app và nhà hàng k phản hồi
# Labels: ('service',)
#
# 📝 Địa chỉ có nhưng k có sđt thì sao gọi để ý kiến món nào sai hay thiếu
# Labels: ('service',)
#
# 📝 xuất bún đầy đủ 55k mà đc nửa hộp cả bún cả đồ
# Labels: ('price',)
#
# 📝 trà sữa mix j như này
# Labels: ('food', 'service')
#
# 📝 lừa à
# Labels: ('service',)
#
# 📝 không có khăn giấy và xiên
# Labels: ('service',)
#
# 📝 em xin nhiều tương hong có cho em ạ
# Labels: ('food', 'service')
#
# 📝 thiếu 1 phần canh
# Labels: ('service',)
#
# 📝 đặt 7 ly mà giao 6 ly
# Labels: ('delivery', 'service')
#
# 📝 xứng đáng KHÔNG SAO
# Labels: ('service',)
#
# 📝 QUÁN CƠM QUÁ KỲ CỤC NGHĨ SAO GIAO CHO KHÁCH 1 HỘP CƠM MỠ KO K CÓ THỊT GÌ HẾT QUÁ
# Labels: ('delivery', 'service')
#
# 📝 nửa con dc có mấy miếng
# Labels: ('price',)
#
# 📝 Chè đậu đỏ được mấy hột đậu đỏ
# Labels: ('price',)
#
# 📝 k bó với số tiền
# Labels: ('price',)
#
# 📝 có chút xíu
# Labels: ('price',)
#
# 📝 23k đc 5 miếng
# Labels: ('price',)
#
# 📝 ăn tô 45k mà lạ lắm
# Labels: ('food', 'price')
#
# 📝 Thanh toán thẻ visa vẫn bị trừ đủ 51k
# Labels: ('price',)
#
# 📝 80 nghìn hả
# Labels: ('price',)
#
# 📝 siêu ít
# Labels: ('price',)
#
# 📝 cảm thấy phí tiền
# Labels: ('price',)
#
# 📝 chỉ được nửa cốc
# Labels: ('price',)
#
# 📝 vài miếng xoài
# Labels: ('price',)
#
# 📝 thấy phí tiền ạ
# Labels: ('price',)
#
# 📝 chặt cho 2 cái cánh với cục xương =)))
# Labels: ('price',)
#
# 📝 rau thì ít
# Labels: ('price',)
#
# 📝 vài cọng rau
# Labels: ('price',)
#
# 📝 mng đừng mua phí tiền nhé
# Labels: ('price',)
#
# 📝 Đc 5 miếng cá chiên quắt queo
# Labels: ('price',)
#
# 📝 trân châu phomai cả ly được có 4-5 viên
# Labels: ('price',)
#
# 📝 Được 2 lát bò
# Labels: ('price',)
#
# 📝 3 cục cá 2 con tôm
# Labels: ('price',)
#
# 📝 hủ tiếu thì quá ít chắc được hai đũa hết rồi
# Labels: ('food', 'price')
#
# 📝 hnay sao bò ít v quán ơi
# Labels: ('food', 'price')
#
# 📝 rất không hài lòng vì em đã note rất kỹ
# Labels: ('service',)
#
# 📝 sao ba phần mà có một bịch nước dùng v
# Labels: ('service',)
#
# 📝 mỏng
# Labels: ('food',)
#
# 📝 chất lượng món ăn bị kém
# Labels: ('food',)
#
# 📝 sốt HS chỗ có chỗ ko kiểu quết lên cho có
# Labels: ('service',)
#
# 📝 nói chúng rất thích món này của lotte
# Labels: ('food', 'service')
#
# 📝 Đóng gói chưa tốt
# Labels: ('service',)
#
# 📝 xin thêm đá nhưng không cho
# Labels: ('service',)
#
# 📝 sai đơn :))
# Labels: ('service',)
#
# 📝 giao sai hết món cho khách
# Labels: ('delivery', 'service')
#
# 📝 xôi ngon
# Labels: ('food',)
#
# 📝 nhưng thịt nguội lạnh
# Labels: ('food',)
#
# 📝 không ngon
# Labels: ('food',)
#
# 📝 nói chung thịt dở
# Labels: ('food',)
#
# 📝 mua hai món giao có 1 món
# Labels: ('delivery', 'service')
#
# 📝 đặt tomyum mà giao vị kim chi lần này lần t2 r ạ
# Labels: ('delivery', 'service')
#
# 📝 nước chấm lạnh ngắt cho 1 tý thôi vậy bà
# Labels: ('food',)
#
# 📝 Quá dở
# Labels: ('food',)
#
# 📝 quá mặn
# Labels: ('food',)
#
# 📝 kem lỏng lẻo giao tới tan thành nước
# Labels: ('delivery', 'food')
#
# 📝 Wrong/Missing items
# Labels: ('service',)
#
# 📝 giao sai đơn hàng
# Labels: ('delivery', 'service')
#
# 📝 treo đầu dê bán thịt chó
# Labels: ('service',)
#
# 📝 lừa đảo khách hàng
# Labels: ('food', 'service')
#
# 📝 thiếu nước uống
# Labels: ('delivery', 'food', 'service')
#
# 📝 k hiểu sao gói đc caia bánh mì như này giao cho khách
# Labels: ('delivery', 'food')
#
# 📝 làm gì đâu ẩu
# Labels: ()
#
# 📝 mì cay thì nước dùng chua lè
# Labels: ('food',)
#
# 📝 sai món
# Labels: ('food', 'service')
#
# 📝 làm 2 phần hạt sen cốt dừa
# Labels: ('food',)
#
# 📝 nhưng khi nhận hàng lại không có phần nước
# Labels: ('service',)
#
# 📝 trong khi 60k(10/1 miếng) Shop làm ăn có tâm giúp mk với
# Labels: ('price',)
#
# 📝 100k lận quán ơi :(
# Labels: ('price',)
#
# 📝 ít xịt
# Labels: ('price',)
#
# 📝 đắt
# Labels: ('price',)
#
# 📝 tôm chiên bột mua thêm được hẳn 3 cục (10k)
# Labels: ('price',)
#
# 📝 20k Còn k ngon bằng bánh mì 6k ngoài tạp hoá
# Labels: ('food', 'price')
#
# 📝 68k đồ ăn siêu ít nói chung cực kì tệ :))
# Labels: ('food', 'price')
#
# 📝 đồ ăn ít mà mắc vãi l
# Labels: ('price',)
#
# 📝 đây là 1 cốc sữa chua 32k ah
# Labels: ('price',)
#
# 📝 đặc phần cháo 35k thịt bằm sườn mà nhận đc có cháo trắng hành lá ớt
# Labels: ('food', 'price')
#
# 📝 làm ăn gì kỳ vậy lấy Ng ta 35k mà làm vậy à
# Labels: ('food', 'price')
#
# 📝 đây là tô bún đặt biệt giá cao nhất 65k
# Labels: ('price',)
#
# 📝 nhiêu đây là bún của phần combo và bún thêm
# Labels: ('price',)
#
# 📝 lần đầu đặt đồ mà ăn thấy phí tiền phí mồm thật sự
# Labels: ('food', 'price')
#
# 📝 chưa bao giờ bỏ tiền ra thấy phí như hiện tại
# Labels: ('price',)
#
# 📝 Trời má cơm có mùi gián :) Ý là cũm 100k hơn chớ đâu phải 1k đâu trời làm như ngộ dị
# Labels: ('food', 'price')
#
# 📝 doi có 4lat mà 30k
# Labels: ('price',)
#
# 📝 order ít đá nhưng để hơn nửa cốc size L là đá
# Labels: ('delivery', 'service')
#
# 📝 không hiểu suất 60k kiểu gì nhìn cái ảnh thì rõ đủ mà ship đến không có chân giò luộc không có rau không có chả cốm nói chung là 60k thì không xứng với đồng tiền
# Labels: ('food', 'price', 'service')
#
# 📝 đồ ăn rất ít
# Labels: ('food', 'price')
#
# 📝 1 trái trứng chiên bán 33k
# Labels: ('price',)
#
# 📝 không cho đũa mà tính tiền
# Labels: ('service',)
#
# 📝 1p gần 50k mà đc 1 miếng thịt mỏng dánh vs 2 cục chả bé tí
# Labels: ('food', 'price')
#
# 📝 Phần 110k đúng như cho chó ăn
# Labels: ('food', 'price')
#
# 📝 RẤT ÍT MÃNG CẦU THẬM CHÍ NHƯ KHÔNG CÓ
# Labels: ('food', 'price', 'service')
#
# 📝 vừa ít vừa dở vừa đắt
# Labels: ('food', 'price')
#
# 📝 ít thịt
# Labels: ('price',)
#
# 📝 đặt suất 52k có coca mà giao thiếu
# Labels: ('delivery', 'price', 'service')
#
# 📝 bưởi đắt như thế mà chai
# Labels: ('delivery', 'price')
#
# 📝 Đặt ly 41k thì giao ly 28k
# Labels: ('delivery', 'price', 'service')
#
# 📝 đặt 2 combo nhưng lại chỉ giao 1
# Labels: ('delivery', 'service')
#
# 📝 Nghĩ sao giao 3 hộp cháo mà hộp nào cũng chua lè vậy trời
# Labels: ('food',)
#
# 📝 giá khôn đúng trên menu
# Labels: ('service',)
#
# 📝 rất ít mà 10k
# Labels: ('food', 'price')
#
# 📝 đồ ăn quá ít
# Labels: ('food', 'price')
#
# 📝 bún ít Quá
# Labels: ('food', 'price')
#
# 📝 ít chả
# Labels: ('price',)
#
# 📝 lơ thơ dc vài cọng bé xíu
# Labels: ('food', 'price')
#
# 📝 khen dc phần rau tươi nhưng rất ít
# Labels: ('food', 'price')
#
# 📝 nc chấm thic như nước lọc vậy với giá tiền này mn mua cái khác mà ăn ạ
# Labels: ('food', 'price')
#
# 📝 xuất cơm vp 50k mà như cơm 20k ao sen
# Labels: ('food', 'price')
#
# 📝 xúc xích chiên đen thui mà giá 15k 1 cái vậy mà cũng giao cho khách được
# Labels: ('food', 'price')
#
# 📝 phí tiền
# Labels: ('price',)
#
# 📝 Nước dùng cho rất ít
# Labels: ('food', 'price')
#
# 📝 bán thì đắt
# Labels: ('price',)
#
# 📝 nchung vừa phí tiền lại bực mình
# Labels: ('price',)
#
# 📝 Ly đặt 36k+ship giao thành ly 22k cho khách
# Labels: ('delivery', 'price', 'service')
#
# 📝 để mà 50 nghìn mua suất cơm này thì không đáng rau ít thịt ít
# Labels: ('food', 'price')
#
# 📝 So với giá gần 130k nữa con gà là quá đắt
# Labels: ('price',)
#
# 📝 nghĩ sao phần 50k cho 2 cục thịt một nhúm bún giỡn mặt hả
# Labels: ('price',)
#
# 📝 15k túi nước chấm dc 1tý này
# Labels: ('food', 'price')
#
# 📝 giáo hàng thất bại
# Labels: ('price',)
#
# 📝 bán mắc mà còn hk ngon nữa
# Labels: ('food', 'price')
#
# 📝 sao cơm rang hải sản có đúng vài con tôm với toàn hành
# Labels: ('food', 'price')
#
# 📝 siêu ít
# Labels: ('price',)
#
# 📝 tưởng cho con nít ăn
# Labels: ('price',)
#
# 📝 Rõ ràng là giá mắc chứ cũng đâu phải rẻ mà mực cũng chẳng tươi
# Labels: ('food', 'price')
#
# 📝 Ly nước dừa không 25k
# Labels: ('price',)
#
# 📝 đặt 4 mì thập cẩm nhiều mì nhưng lại ít mì hơn mọi khi
# Labels: ('food', 'price')
#
# 📝 mua 1 ly full topping tặng ly nguyên lá xong thiếu hết ly trà sữa trân châu đen 30k của ngta
# Labels: ('delivery', 'price', 'service')
#
# 📝 k xứng giá tiền
# Labels: ('price',)
#
# 📝 vậy mà lấy giá tiền lại cao
# Labels: ('price',)
#
# 📝 sao e đặt thêm đồ r mà ít vậy ạ ko có thịt nướngcos
# Labels: ('food', 'price', 'service')
#
# 📝 88k xuất full toping
# Labels: ('price',)
#
# 📝 40k bát bún chưa kể ship mã app mà nó ít bún ít thịt mọc 2 miếng quá tệ
# Labels: ('food', 'price')
#
# 📝 Dở nước lỏng ít thịt k đáng tiền
# Labels: ('food', 'price')
#
# 📝 75k mà đc 1 miếng sườn
# Labels: ('price',)
#
# 📝 QUÁ TỆ VỚI GIÁ 75K
# Labels: ('price',)
#
# 📝 uống còn không bằng trà sữa 10k ngoài cổng trường
# Labels: ('food', 'price')
#
# 📝 cảm thấy phí tiền
# Labels: ('price',)
#
# 📝 bán gì mắc thế
# Labels: ('price',)
#
# 📝 không với giá cả
# Labels: ('price',)
#
# 📝 chọn combo 3 cái dồi sụn mà giao có 1
# Labels: ('delivery', 'service')
#
# 📝 phần gỏi 120k quá mắc so với chất lượng
# Labels: ('food', 'price')
#
# 📝 cháo này cho trẻ con ăn thì đủ
# Labels: ('food', 'price')
#
# 📝 ê tính ra 45k 1 tô đặc biệt :) là đặc biệt chưa má
# Labels: ('price', 'service')
#
# 📝 sủi cảo 50k mà chưa đến 8 cục sủi cảo nữa
# Labels: ('price',)
#
# 📝 set 2-3 ng ăn mà ít dữ vậy trời -)
# Labels: ('food', 'price')
#
# 📝 45k suất bún
# Labels: ('food', 'price')
#
# 📝 ơi là trời một tô 63k quá không xứng đáng
# Labels: ('price',)
#
# 📝 đặt khoai tây chiên ship mang khoai lang chiên
# Labels: ('delivery', 'service')
#
# 📝 không liên hệ khách tự đổi món
# Labels: ('delivery', 'service')
#
# 📝 mình không hiểu vì sao mình đặt 3 suất bạn giao 2 suất và 3 hộp nước chấm
# Labels: ('delivery', 'service')
#
# 📝 chậm
# Labels: ('delivery',)
#
# 📝 b có giao nhầm đơn của mình k vậy
# Labels: ('delivery',)
#
# 📝 mình có đặt quẩy sao k thấy cửa hàng giao ạ
# Labels: ('delivery', 'service')
#
# 📝 giao nhầm size đặt L giao size M
# Labels: ('delivery', 'service')
#
# 📝 dặn mắm ngọt mà giao mắm tôm
# Labels: ('delivery', 'service')
#
# 📝 đặt gà thường giao gà ncmắm
# Labels: ('delivery', 'service')
#
# 📝 đặt tôm thịt bằm nhưng ship tới chỉ có thịt không có tôm
# Labels: ('delivery', 'service')
#
# 📝 Giao thiếu đồ
# Labels: ('delivery', 'service')
#
# 📝 canh bị đổ hết sao ăn
# Labels: ('delivery',)
#
# 📝 giao thiếu món
# Labels: ('delivery', 'service')
#
# 📝 giao hàng k có nem
# Labels: ('delivery', 'service')
#
# 📝 tài xế làm phiền nhiều lần
# Labels: ()
#
# 📝 quá lâu
# Labels: ('delivery',)
#
# 📝 nhanh
# Labels: ('delivery',)
#
# 📝 đặt suất 50k đầy đủ nhận lại được như thế này đây
# Labels: ('price',)
#
# 📝 49k cho 1 hộp xôi như thế mình cảm thấy không hợp lí
# Labels: ('price', 'service')
#
# 📝 đặt 7 ly giao lộn 1 ly
# Labels: ('delivery', 'service')
#
# 📝 đặt bún bò giao bún mắm
# Labels: ('delivery', 'service')
#
# 📝 đã giao lộn mà còn thái độ
# Labels: ('delivery', 'service')
#
# 📝 hộp cơm sườn trứng 45k mà giao cơm với trứng thui
# Labels: ('delivery', 'food', 'price', 'service')
#
# 📝 giao sai cả đơn hàng
# Labels: ('delivery', 'service')
#
# 📝 thiếu món giao sai cả những thúe mình đặt
# Labels: ('delivery', 'service')
#
# 📝 Đặt 3 phần giao 2 phần
# Labels: ('delivery',)
#
# 📝 Đặt mì với nước mà chỉ giao mì không giao nước
# Labels: ('delivery', 'service')
#
# 📝 Đã thanh toán tiền qua thẻ nhưng shop vẫn đòi shipper tiền
# Labels: ('service',)
#
# 📝 đặt 4 phần mà shop giao 2
# Labels: ('delivery', 'service')
#
# 📝 đặt trà sữa nhãn sen mà giao trà nhãn sen
# Labels: ('delivery', 'service')
#
# 📝 Thêm trân châu đen nhưng lại là trắng
# Labels: ('delivery', 'service')
#
# 📝 nhân viên như db tao thái độ như cakk
# Labels: ('service',)
#
# 📝 Đặt 2 miếng gà không cay mà giao 2 miếng gà cay
# Labels: ('delivery', 'service')
#
# 📝 pvu kém giao sai ko thấy có đúng 1 món nào
# Labels: ('delivery', 'service')
#
# 📝 đặt trà sen vàng nhưng giao qua lại là cà phê
# Labels: ('delivery', 'service')
#
# 📝 đặt cà phê đá size lớn nhưng giao cà phê size nhỏ
# Labels: ('delivery', 'service')
#
# 📝 1 phần 50k như vậy là quá đắt
# Labels: ('price',)
#
# 📝 đặt 2 hộp giao còn có 1 hộp
# Labels: ('delivery', 'service')
#
# 📝 hình ảnh là 4 cốc nhưng mà giao 3
# Labels: ('delivery', 'service')
#
# 📝 đang đói mà còn thiếu cái thật sự
# Labels: ('delivery', 'service')
#
# 📝 giao thiếu phần gà
# Labels: ('delivery', 'service')
#
# 📝 có đặt 1 phần phở thêm nhưng không thấy có
# Labels: ('delivery', 'service')
#
# 📝 giao thíu 1c nem nướng nha má
# Labels: ('delivery', 'service')
#
# 📝 ủa sao ship chưa giao hàng cho mình mà kêu giao thành công
# Labels: ('delivery',)
#
# 📝 Mà từ chỗ mình đến quán mất có 5-7p shipper giao nhanh
# Labels: ('delivery', 'price')
#
# 📝 điểm cộng: giao nhanh
# Labels: ('delivery',)
#
# 📝 giao nhanh mà thiếu bánh tart nên hơi bực nha☺️
# Labels: ('delivery', 'service')
#
# 📝 giao nhanh nhưng cháo nát
# Labels: ('delivery', 'food', 'service')
#
# 📝 mặc dù tài xế giao nhanh nha
# Labels: ('delivery',)
#
# 📝 có vẻ sạch sẽ
# Labels: ('ambience',)
#
# 📝 Đóng gói riêng từng phần nhìn chỉn chu
# Labels: ('ambience', 'service')
#
# 📝 có lẽ do khâu vệ sinh đóng gói là nhiều
# Labels: ('ambience',)
#
# 📝 khoai tay chiên nóng cho thẳng vào hộp nhựa gây biến dạng hộp
# Labels: ('service',)
#
# 📝 cảm giác hơi bẩn
# Labels: ('ambience',)
#
# 📝 sạch sẽ
# Labels: ('ambience',)
#
# 📝 shipper thân thiện quá chừng ^^
# Labels: ('delivery',)
#
# 📝 đến 11h quán báo không có shipper rồi tự ý huỷ đơn hàng
# Labels: ('delivery',)
#
# 📝 Lúc lấy bịch đồ ăn từ bạn shipper là mình đã bị sốc vì cái hộp nui nhìn quá là rẻ tiền
# Labels: ('delivery', 'price')
#
# 📝 Mình thích không gian ở đây lắm luôn
# Labels: ('ambience',)
#
# 📝 có hẳn cả khu cây xanh thác nước mini chảy róc rách
# Labels: ('ambience',)
#
# 📝 thoáng mát và có cả khu hồ nước
# Labels: ('ambience',)
#
# 📝 thoáng mát với phong cảnh hồ nước
# Labels: ('ambience',)
#
# 📝 Không gian thoáng do có giếng trời
# Labels: ('ambience',)
#
# 📝 Tìm được một nơi vừa thoải mái vừa thoáng mát
# Labels: ('ambience',)
#
# 📝 nhà hàng sạch sẽ thoáng mát rất sang trọng và lịch sự
# Labels: ('ambience',)
#
# 📝 Không gian sang trọng nhưng ấm cúng
# Labels: ('ambience',)
#
# 📝 Không gian sang nhưng hơi ồn
# Labels: ('ambience',)
#
# 📝 Quán sang chảnh
# Labels: ('ambience',)
#
# 📝 trang trí siêu đẹp
# Labels: ('ambience',)
#
# 📝 Nhà hàng trông cũng sang trọng
# Labels: ('ambience',)
#
# 📝 không gian hiện đại
# Labels: ('ambience',)
#
# 📝 phong cách Châu Âu chuẩn ăn rất lịch sự
# Labels: ('ambience',)
#
# 📝 Phục vụ bồi bàn thì lịch sự
# Labels: ('service',)
#
# 📝 nhân viên phúc vụ hầu hết đều lịch sự
# Labels: ('service',)
#
# 📝 Nhưng không gian chật quá
# Labels: ('ambience',)
#
# 📝 buổi trưa đông khách ngồi khá chật
# Labels: ('ambience',)
#
# 📝 Quán khá chật và nóng
# Labels: ('ambience',)
#
# 📝 Không gian nguyên bản đã chật
# Labels: ('ambience',)
#
# 📝 nhà hàng nằm trên đường Mạc Đĩnh Chi hơi hẹp
# Labels: ('ambience',)
#
# 📝 Phía ngoài trước phòng cưới hơi hẹp
# Labels: ('ambience',)
#
# 📝 Nghe nói dạo gần đây quán thu hẹp không gian lại rồi
# Labels: ('ambience',)
#
# 📝 đằng trước quán hơi hẹp
# Labels: ('ambience',)
#
# 📝 Mình đi lúc quán vừa mở cửa nên hơi nóng và có mùi hơi kì
# Labels: ('ambience',)
#
# 📝 Vừa bước vào quán đã thấy nóng
# Labels: ('ambience',)
#
# 📝 Không gian máy lạnh nên ăn bún cũng khá thích
# Labels: ('ambience',)
#
# 📝 có máy lạnh mát mẻ
# Labels: ('ambience',)
#
# 📝 phòng máy lạnh ở tầng trên
# Labels: ('ambience',)
#
# 📝 nhân viên ở đây khá nhiệt tình
# Labels: ('service',)
#
# 📝 nhân viên dễ thương đến vậy nhỉ
# Labels: ('service',)
#
# 📝 nhân viên thì chu đáo nhiệt tình
# Labels: ('service',)
#
# 📝 nhân viên phục vụ thì bất lịch sự
# Labels: ('service',)
#
# 📝 nhân viên vẫn láo như xưa
# Labels: ('service',)
#
# 📝 Không gian quán bẩn từ tường đến bàn ăn
# Labels: ('ambience',)
#
# 📝 Nhưng nền nhà ghê quá
# Labels: ('ambience',)
#
# 📝 quán thì dơ bẩn
# Labels: ('ambience',)
#
# 📝 rau thì bẩn rửa không sạch còn nguyên nước
# Labels: ('food',)
#
# 📝 Có để thùng rác dưới mỗi bàn nhưng sàn vẫn khá là bẩn!
# Labels: ('ambience',)
#
# 📝 còn cả dây bao trong đá
# Labels: ('food',)
#
# 📝 phòng vệ sinh vẫn còn đang lau dọn ẩm ướt
# Labels: ('ambience',)
#
# 📝 quán nhìn bẩn nhất so với các chi nhánh khác😖😤😡
# Labels: ('ambience',)
#
# 📝 Mình có nhận xét là ghế ở đây bụi bẩn không sạch
# Labels: ('ambience',)
#
# 📝 yen tinh
# Labels: ('ambience',)
#
# 📝 am cung
# Labels: ('ambience',)
#
# 📝 Khong gian nho
# Labels: ('ambience',)
#
# 📝 Quá đẹp quá lang man luôn cho này chụp hình cuoi bao đẹp
# Labels: ('ambience',)
#
# 📝 thoáng và hơi lãng mạn
# Labels: ('ambience',)
#
# 📝 bằng thủy tinh nên có thể nhìn thấy  lửa liu riu ở dưới trông rất lãng mạn
# Labels: ('ambience',)

# %% [markdown]
# # Classification : Positive, Negative, Neutral

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset
import pandas as pd
import torch
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
# 1. Đọc và xử lý dữ liệu
df = pd.read_csv("label_sentiment.csv")  # cột 'components', 'sentiment'
df = df.dropna(subset=["sentiment"])

label_map = {"NEG": 0, "NEU": 1, "POS": 2}
df["label_id"] = df["sentiment"].map(label_map)

# %%
df
# Out:
#                                              components sentiment  label_id
# 0                                              Ngon xỉu       POS         2
# 1                                        Đáng đồng tiền       POS         2
# 2                                               Sạch sẽ       POS         2
# 3                                          Đóng gói tốt       POS         2
# 5                                         Làm món nhanh       POS         2
# ...                                                 ...       ...       ...
# 1097          Tuy nhiên cần chú ý đến ghi chú của khách       NEU         1
# 1098                                       Bánh hơi béo       NEU         1
# 1099                                       hơi đắt 1 tí       NEU         1
# 1100  do ăn hơi đắt nha so với quảng cáo 1 khoanh cá...       NEU         1
# 1101                        bánh xèo hơi nhiều dầu chút       NEU         1
#
# [1100 rows x 3 columns]

# %%
# 2. Tách train/test
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df["components"].tolist(),
    df["label_id"].tolist(),
    test_size=0.2,
    stratify=df["label_id"],
    random_state=42
)

# %%
# 3. Tokenizer
model_id = "wonrax/phobert-base-vietnamese-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/285 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
# 4. Dataset class
class SentimentDataset(Dataset):
    def __init__(self, texts, labels):
        self.encodings = tokenizer(texts, padding=True, truncation=True, max_length=128)
        self.labels = labels

    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
        item["labels"] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = SentimentDataset(train_texts, train_labels)
val_dataset = SentimentDataset(val_texts, val_labels)

# %%
# 5. Load model
model = AutoModelForSequenceClassification.from_pretrained(model_id, num_labels=3)

# %%
pwd
# Out:
# '/content'

# %%
# 6. Huấn luyện
training_args = TrainingArguments(
    output_dir="./results",                # nơi lưu model
    num_train_epochs=10,                    # số epoch
    per_device_train_batch_size=8,        # batch size train
    per_device_eval_batch_size=8,         # batch size eval
    logging_dir="./logs",                  # nơi lưu log
    logging_steps=100,                     # log mỗi 100 bước
    save_total_limit=1,                    # chỉ giữ 1 checkpoint mới nhất
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

trainer.train()
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
#     <div>
#
#       <progress value='1100' max='1100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1100/1100 1:37:03, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.643300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.289500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.230500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.116700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.069900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.049200</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.042500</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.045000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.010600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.025400</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.020200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1100, training_loss=0.14025829141790216, metrics={'train_runtime': 5833.8028, 'train_samples_per_second': 1.508, 'train_steps_per_second': 0.189, 'total_flos': 140190117883200.0, 'train_loss': 0.14025829141790216, 'epoch': 10.0})
